# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
location = "Kickstartercombo.csv"
df = pd.read_csv(location)

df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
df.count()
# Out:
# Unnamed: 0          702411
# ID                  702411
# name                702403
# main_category       702411
# category            702411
# country             702411
# state               702411
# goal                702411
# pledged             702411
# currency            702411
# launched            702411
# deadline            702411
# backers             702411
# usd pledged         694817
# usd_goal_real       378661
# usd_pledged_real    378661
# dtype: int64

# %%
dupe = df.duplicated()
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, name, main_category, category, country, state, goal, pledged, currency, launched, deadline, backers, usd pledged, usd_goal_real, usd_pledged_real]
# Index: []

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# name                     8
# main_category            0
# category                 0
# country                  0
# state                    0
# goal                     0
# pledged                  0
# currency                 0
# launched                 0
# deadline                 0
# backers                  0
# usd pledged           7594
# usd_goal_real       323750
# usd_pledged_real    323750
# dtype: int64

# %%
df.groupby(['main_category', 'state'])['goal','pledged'].count()
# Out:
#                            goal  pledged
# main_category state
# Art           canceled     4113     4113
#               failed      26259    26259
#               live          450      450
#               successful  21187    21187
#               suspended     168      168
# Comics        canceled     1545     1545
#               failed       7446     7446
#               live          193      193
#               successful  10349    10349
#               suspended      42       42
# Crafts        canceled     1525     1525
#               failed      10340    10340
#               live          218      218
#               successful   3788     3788
#               suspended     130      130
# Dance         canceled      300      300
#               failed       2326     2326
#               live           50       50
#               successful   4442     4442
#               suspended      25       25
#               undefined       2        2
# ...

# %%
df.groupby(['main_category','state']).count()
# Out:
#                           Unnamed: 0     ID   name  category  country   goal  \
# main_category state
# Art           canceled          4113   4113   4113      4113     4113   4113
#               failed           26259  26259  26257     26259    26259  26259
#               live               450    450    450       450      450    450
#               successful       21187  21187  21187     21187    21187  21187
#               suspended          168    168    168       168      168    168
# Comics        canceled          1545   1545   1545      1545     1545   1545
#               failed            7446   7446   7446      7446     7446   7446
#               live               193    193    193       193      193    193
#               successful       10349  10349  10349     10349    10349  10349
#               suspended           42     42     42        42       42     42
# Crafts        canceled          1525   1525   1525      1525     1525   1525
# ...

# %%
df=df.loc[df['main_category']=='Food']
df
# Out:
#         Unnamed: 0          ID  \
# 4                4  1000014025
# 5                5  1000023410
# 6                6  1000030581
# 17              17  1000071625
# 20              20  1000087442
# 26              26  1000115172
# 39              39  1000183112
# 47              47  1000217634
# 55              55  1000235643
# 65              65  1000282287
# 79              79  1000340977
# 89              89  1000399155
# 95              95  1000428719
# 101            101  1000476123
# 110            110  1000521061
# 179            179  1000834930
# 202            202   100101389
# 218            218  1001087682
# 220            220  1001115961
# 224            224  1001135664
# 231            231  1001157858
# 257            257  1001302832
# 269            269  1001352451
# 277            277  1001432466
# 283            283  1001473842
# 285            285  1001484182
# 298            298  1001543887
# 309            309  1001578248
# 331            331  1001762923
# ...

# %%
df2=df.drop(['Unnamed: 0','usd pledged', 'usd_goal_real','usd_pledged_real'], axis =1)
df2
# Out:
#                 ID                                               name  \
# 4       1000014025                               Monarch Espresso Bar
# 5       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 6       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 17      1000071625                                           Boco Tea
# 20      1000087442  Mountain brew: A quest for alcohol sustainability
# 26      1000115172                                  Daily Brew Coffee
# 39      1000183112                            Hot Chicken Takes Over.
# 47      1000217634                 Mobile barbecue & catering trailer
# 55      1000235643                                       HIIT Bottle
# 65      1000282287  Babe Ruth's Family Kitchen - Gourmet Hot Dogs ...
# 79      1000340977                                      My Coffee Box
# 89      1000399155                                        New Lasagna
# ...

# %%
df2.groupby(['state']).count()
# Out:
#                ID   name  main_category  category  country   goal  pledged  \
# state
# canceled     4146   4146           4146      4146     4146   4146     4146
# failed      29601  29601          29601     29601    29601  29601    29601
# live          464    464            464       464      464    464      464
# successful  11352  11352          11352     11352    11352  11352    11352
# suspended     281    281            281       281      281    281      281
#
#             currency  launched  deadline  backers
# state
# canceled        4146      4146      4146     4146
# failed         29601     29601     29601    29601
# live             464       464       464      464
# successful     11352     11352     11352    11352
# suspended        281       281       281      281

# %%
df.sum()
df
# Out:
#         Unnamed: 0          ID  \
# 4                4  1000014025
# 5                5  1000023410
# 6                6  1000030581
# 17              17  1000071625
# 20              20  1000087442
# 26              26  1000115172
# 39              39  1000183112
# 47              47  1000217634
# 55              55  1000235643
# 65              65  1000282287
# 79              79  1000340977
# 89              89  1000399155
# 95              95  1000428719
# 101            101  1000476123
# 110            110  1000521061
# 179            179  1000834930
# 202            202   100101389
# 218            218  1001087682
# 220            220  1001115961
# 224            224  1001135664
# 231            231  1001157858
# 257            257  1001302832
# 269            269  1001352451
# 277            277  1001432466
# 283            283  1001473842
# 285            285  1001484182
# 298            298  1001543887
# 309            309  1001578248
# 331            331  1001762923
# ...

# %%
df=df.drop(['Unnamed: 0','usd pledged', 'usd_goal_real','usd_pledged_real'], axis =1)
df
# Out:
#                 ID                                               name  \
# 4       1000014025                               Monarch Espresso Bar
# 5       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 6       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 17      1000071625                                           Boco Tea
# 20      1000087442  Mountain brew: A quest for alcohol sustainability
# 26      1000115172                                  Daily Brew Coffee
# 39      1000183112                            Hot Chicken Takes Over.
# 47      1000217634                 Mobile barbecue & catering trailer
# 55      1000235643                                       HIIT Bottle
# 65      1000282287  Babe Ruth's Family Kitchen - Gourmet Hot Dogs ...
# 79      1000340977                                      My Coffee Box
# 89      1000399155                                        New Lasagna
# ...

# %%
corr = df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('pledged ~ backers', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                pledged   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                 4.644e+04
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        20:10:52   Log-Likelihood:            -5.1435e+05
# No. Observations:               45844   AIC:                         1.029e+06
# Df Residuals:                   45841   BIC:                         1.029e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -86.9699     86.155     -1.009      0.313    -255.836      81.896
# ...

# %%
sns.countplot(x='category', data=df)

# %%
sns.barplot('category', 'pledged', data=df)

# %%
sns.barplot('category', 'goal', data=df)

# %%
sns.barplot('category', 'backers', data=df)

# %%
sns.lmplot(x='pledged', y='backers', data=df)

# %%
sns.boxplot(data=df)

# %%
stats_df = df.drop(['ID', 'goal'], axis=1)
stats_df.head()
# Out:
#                                                  name main_category  \
# 4                                Monarch Espresso Bar          Food
# 5   Support Solar Roasted Coffee & Green Energy!  ...          Food
# 6   Chaser Strips. Our Strips make Shots their B*tch!          Food
# 17                                           Boco Tea          Food
# 20  Mountain brew: A quest for alcohol sustainability          Food
#
#        category country       state  pledged currency             launched  \
# 4   Restaurants      US  successful  52375.0      USD  2016-02-26 13:38:00
# 5          Food      US  successful   1205.0      USD  2014-12-01 18:30:00
# 6        Drinks      US      failed    453.0      USD  2016-02-01 20:05:00
# 17         Food      US      failed   1781.0      USD  2012-05-03 17:24:00
# 20       Drinks      NO      failed     48.0      NOK  2015-01-26 19:17:00
#
#                deadline  backers
# 4   2016-04-01 13:38:00      224
# 5   2014-12-21 18:30:00       16
# ...

# %%
sns.boxplot(data=stats_df)

# %%
plt.subplots(figsize=(13,7))


#violin plot shows the distribution of attack power for each type
sns.violinplot(x='category', y='pledged', data=df)

# %%
plt.subplots(figsize=(13,7))


#violin plot shows the distribution of attack power for each type
sns.violinplot(x='category', y='backers', data=df)

# %%
from sklearn.linear_model import LinearRegression

X = df.drop(['goal'], axis=1)

lm = LinearRegression()

lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.fit(X, df.goal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-3be12c8ab019> in <module>
# ----> 1 lm.fit(X, df.goal)
#
# ~/anaconda3_501/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3_501/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
